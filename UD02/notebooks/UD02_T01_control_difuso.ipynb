# %% [markdown]
# # UD02 · Taller 1 — Control difuso con scikit-fuzzy
#
# **Objetivo**: construir un sistema de control difuso tipo Mamdani que decida la velocidad de un ventilador según la temperatura y la humedad de una sala.

# %% [markdown]
# ## Fase 1 — Importa las librerías y define los universos
#
# Define tres variables: `temperatura` (0-40), `humedad` (0-100) y `velocidad` (0-100).

# %%
# %pip install scikit-fuzzy

import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# TU CÓDIGO: define los tres Antecedent/Consequent (temperatura 0-40, humedad 0-100, velocidad 0-100)
temperatura = ...
humedad = ...
velocidad = ...

# %% [markdown]
# ## Fase 2 — Funciones de pertenencia
#
# Define:
# - `temperatura`: `fresca` (triangular, 0-0-18), `agradable` (triangular, 15-22-28), `caliente` (trapezoidal, 24-30-40-40).
# - `humedad`: `seca` (triangular, 0-0-45), `media` (triangular, 35-55-75), `humeda` (trapezoidal, 60-75-100-100).
# - `velocidad`: `baja` (triangular, 0-0-40), `media` (triangular, 25-50-75), `alta` (triangular, 60-100-100).

# %%
# TU CÓDIGO: funciones de pertenencia de las tres variables
...

# %% [markdown]
# ## Fase 3 — Reglas IF-THEN
#
# Escribe estas tres reglas:
# 1. SI `temperatura` es `fresca` Y `humedad` es `seca` ENTONCES `velocidad` es `baja`.
# 2. SI `temperatura` es `agradable` Y `humedad` es `media` ENTONCES `velocidad` es `media`.
# 3. SI `temperatura` es `caliente` O `humedad` es `humeda` ENTONCES `velocidad` es `alta`.

# %%
# TU CÓDIGO
r1 = ...
r2 = ...
r3 = ...

# %% [markdown]
# ## Fase 4 — Sistema y simulación
#
# Monta el `ControlSystem` con las tres reglas y simula con (temperatura=20, humedad=50) y con (temperatura=33, humedad=85). Imprime la velocidad resultante en cada caso.

# %%
# TU CÓDIGO
sistema = ...
sim = ...
print(...)

# %% [markdown]
# ## Fase 5 — Visualiza las funciones de pertenencia

# %%
# TU CÓDIGO
velocidad.view()

# %% [markdown]
# ## Fase 6 — Experimento
#
# Calcula la velocidad para estas cuatro combinaciones y anota si te parece un resultado coherente:
#
# | Temperatura | Humedad | Velocidad (%) | ¿Coherente? |
# |---|---|---|---|
# | 10 | 30 | | |
# | 25 | 50 | | |
# | 38 | 90 | | |
# | 18 | 80 | | |

# %%
# TU CÓDIGO: calcula la velocidad para las 4 combinaciones de la tabla anterior
...

# %% [markdown]
# **✏️ Respuesta**: copia la tabla de la Fase 6 aquí ya completada, y comenta si algún resultado te sorprende y por qué.
#
# *(escribe aquí)*
